# %%
# Import packages
import pandas as pd
import json
import re
from pandas.io.json import json_normalize
from IPython.display import display, HTML

# %%
# Files path
business_file = 'Dataset/yelp_academic_dataset_business.json'
census_file = 'Dataset/sub-est2017_all.csv'
zipcode_file = 'Dataset/zipcode_database.csv'

# %%
# Read in data as DataFrame
business_df = pd.read_json(business_file, lines=True)
census_df = pd.read_csv(census_file)
zipcode_df = pd.read_csv(zipcode_file)
# Out:
# /Users/supeng-wen/miniconda2/envs/cp1/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
display(business_df.head())
display(business_df.tail())
display(business_df.info())
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {u'BusinessParking': u'{'garage': False, 'stre...
# 1                       {u'RestaurantsTableService': u'False', u'GoodF...
# 2  1335 rue Beaubien E  {u'RestaurantsTableService': u'True', u'GoodFo...
# 3      211 W Monroe St                                               None
# 4  2005 Alyth Place SE           {u'BusinessAcceptsCreditCards': u'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
#         city                                              hours  is_open  \
# 0    Calgary  {u'Monday': u'8:30-17:0', u'Tuesday': u'11:0-2...        1
# 1  Henderson  {u'Sunday': u'17:0-23:0', u'Friday': u'17:0-23...        0
# 2   Montréal  {u'Monday': u'10:0-22:0', u'Tuesday': u'10:0-2...        0
# 3    Phoenix                                               None        1
# 4    Calgary  {u'Friday': u'8:0-17:0', u'Tuesday': u'8:0-17:...        1
#
#     latitude   longitude                  name               neighborhood  \
# 0  51.091813 -114.031675  Minhas Micro Brewery
# 1  35.960734 -114.939821   CK'S BBQ & Catering
# 2  45.540503  -73.599300         La Bastringue  Rosemont-La Petite-Patrie
# 3  33.449999 -112.076979       Geico Insurance
# 4  51.035591 -114.027366         Action Engine
#
#   postal_code  review_count  stars state
# 0     T2E 6L6            24    4.0    AB
# 1       89002             3    4.5    NV
# 2     H2G 1K7             5    4.0    QC
# 3       85003             8    1.5    AZ
# 4     T2H 0N5             4    2.0    AB
#                           address  \
# 188588  8000 McKnight Rd, Ste 570
# 188589          3341 Babcock Blvd
# 188590            5825 Thunder Rd
# 188591    7601 Scott Padgett Pkwy
# 188592    3900 Paradise Rd, Ste R
#
#                                                attributes  \
# 188588  {u'AcceptsInsurance': u'False', u'ByAppointmen...
# 188589                                               None
# 188590  {u'BusinessParking': u'{'garage': False, 'stre...
# 188591  {u'BusinessAcceptsCreditCards': u'True', u'Res...
# 188592  {u'BusinessParking': u'{'garage': False, 'stre...
#
#                    business_id  \
# 188588  sMQAZ3DkfrURFoJAyOhjEw
# 188589  6hvuCibNS4uECetHb9MCQQ
# 188590  KleCXFYOmdACcQUvf6_XEg
# 188591  3_fIsSxN2RBovQ_6EFtLzA
# 188592  NkOvIueadjFUxeCyq_uQEw
#
#                                                categories        city  \
# 188588        Skin Care, Beauty & Spas, Day Spas, Massage  Pittsburgh
# 188589  Fashion, Women's Clothing, Accessories, Bridal...  Pittsburgh
# 188590  Mobile Phones, Shopping, Department Stores, Fo...     Concord
# 188591  Event Planning & Services, Hotels & Travel, Ho...     Concord
# 188592  Makeup Artists, Men's Clothing, Swimwear, Shop...   Las Vegas
#
#                                                     hours  is_open   latitude  \
# 188588  {u'Monday': u'10:0-21:0', u'Tuesday': u'10:0-2...        0  40.551152
# 188589                                               None        1  40.534242
# 188590  {u'Monday': u'0:0-0:0', u'Tuesday': u'0:0-0:0'...        1  35.378669
# 188591  {u'Monday': u'0:0-0:0', u'Tuesday': u'0:0-0:0'...        1  35.364366
# 188592  {u'Tuesday': u'11:0-19:0', u'Friday': u'11:0-1...        1  36.118697
#
#          longitude                             name neighborhood postal_code  \
# 188588  -80.021213                     Ross Massage                    15237
# 188589  -80.019556            Four Seasons Boutique                    15237
# 188590  -80.724733              Walmart Supercenter                    28027
# 188591  -80.703454  Residence Inn Charlotte Concord                    28027
# 188592 -115.154269     Tito Jimy Salon and Boutique     Eastside       89169
#
#         review_count  stars state
# 188588             9    2.5    PA
# 188589             5    2.0    PA
# 188590            26    3.0    NC
# 188591            19    4.0    NC
# 188592             8    4.0    NV
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188593 entries, 0 to 188592
# Data columns (total 15 columns):
# address         188593 non-null object
# attributes      162807 non-null object
# business_id     188593 non-null object
# categories      188052 non-null object
# city            188593 non-null object
# hours           143791 non-null object
# is_open         188593 non-null int64
# latitude        188587 non-null float64
# longitude       188587 non-null float64
# name            188593 non-null object
# neighborhood    188593 non-null object
# postal_code     188593 non-null object
# review_count    188593 non-null int64
# stars           188593 non-null float64
# state           188593 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 21.6+ MB
# None

# %%
display(census_df.head())
display(census_df.tail())
display(census_df.info())
# Out:
#    SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  PRIMGEO_FLAG FUNCSTAT  \
# 0      40      1       0      0       0       0             0        A
# 1     162      1       0    124       0       0             0        A
# 2     162      1       0    460       0       0             0        A
# 3     162      1       0    484       0       0             0        A
# 4     162      1       0    676       0       0             0        A
#
#               NAME   STNAME CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 0          Alabama  Alabama       4779736            4780135          4785579
# 1   Abbeville city  Alabama          2688               2688             2684
# 2  Adamsville city  Alabama          4522               4522             4516
# 3     Addison town  Alabama           758                754              751
# 4       Akron town  Alabama           356                356              355
#
#    POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0          4798649          4813946          4827660          4840037
# 1             2677             2629             2612             2595
# 2             4502             4479             4457             4437
# 3              751              744              743              740
# 4              345              345              341              337
#
#    POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017
# 0          4850858          4860545          4874747
# 1             2587             2575             2567
# 2             4409             4376             4347
# 3              734              734              728
# 4              335              332              332
#        SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  PRIMGEO_FLAG FUNCSTAT  \
# 81541     157     56      43  99990       0       0             1        F
# 81542      50     56      45      0       0       0             0        A
# 81543     157     56      45  56215       0       0             1        A
# 81544     157     56      45  79125       0       0             1        A
# 81545     157     56      45  99990       0       0             1        F
#
#                              NAME   STNAME CENSUS2010POP  ESTIMATESBASE2010  \
# 81541  Balance of Washakie County  Wyoming          2786               2786
# 81542               Weston County  Wyoming          7208               7208
# 81543              Newcastle city  Wyoming          3532               3533
# 81544                  Upton town  Wyoming          1100               1100
# 81545    Balance of Weston County  Wyoming          2576               2575
#
#        POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 81541             2787             2761             2740             2743
# 81542             7198             7141             7074             7136
# 81543             3530             3505             3472             3480
# 81544             1098             1089             1083             1090
# 81545             2570             2547             2519             2566
#
#        POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017
# 81541             2696             2698             2660             2618
# 81542             7142             7181             7198             6927
# 81543             3482             3495             3514             3389
# 81544             1098             1102             1104             1060
# 81545             2562             2584             2580             2478
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81546 entries, 0 to 81545
# Data columns (total 20 columns):
# SUMLEV               81546 non-null int64
# STATE                81546 non-null int64
# COUNTY               81546 non-null int64
# PLACE                81546 non-null int64
# COUSUB               81546 non-null int64
# CONCIT               81546 non-null int64
# PRIMGEO_FLAG         81546 non-null int64
# FUNCSTAT             81546 non-null object
# NAME                 81546 non-null object
# STNAME               81546 non-null object
# CENSUS2010POP        81546 non-null object
# ESTIMATESBASE2010    81546 non-null int64
# POPESTIMATE2010      81546 non-null int64
# POPESTIMATE2011      81546 non-null int64
# POPESTIMATE2012      81546 non-null int64
# POPESTIMATE2013      81546 non-null int64
# POPESTIMATE2014      81546 non-null int64
# POPESTIMATE2015      81546 non-null int64
# POPESTIMATE2016      81546 non-null int64
# POPESTIMATE2017      81546 non-null int64
# dtypes: int64(16), object(4)
# memory usage: 12.4+ MB
# None

# %%
display(zipcode_df.head())
display(zipcode_df.tail())
display(zipcode_df.info())
# Out:
#    RecordNumber  Zipcode ZipCodeType                 City State  \
# 0             1      704    STANDARD          PARC PARQUE    PR
# 1             2      704    STANDARD  PASEO COSTA DEL SUR    PR
# 2             3      704    STANDARD        SECT LANAUSSE    PR
# 3             4      704    STANDARD      URB EUGENE RICE    PR
# 4             5      704    STANDARD         URB GONZALEZ    PR
#
#      LocationType    Lat   Long  Xaxis  Yaxis  Zaxis WorldRegion Country  \
# 0  NOT ACCEPTABLE  17.96 -66.22   0.38  -0.87    0.3         NaN      US
# 1  NOT ACCEPTABLE  17.96 -66.22   0.38  -0.87    0.3         NaN      US
# 2  NOT ACCEPTABLE  17.96 -66.22   0.38  -0.87    0.3         NaN      US
# 3  NOT ACCEPTABLE  17.96 -66.22   0.38  -0.87    0.3         NaN      US
# 4  NOT ACCEPTABLE  17.96 -66.22   0.38  -0.87    0.3         NaN      US
#
#               LocationText                      Location  Decommisioned  \
# 0          Parc Parque, PR          NA-US-PR-PARC PARQUE          False
# 1  Paseo Costa Del Sur, PR  NA-US-PR-PASEO COSTA DEL SUR          False
# 2        Sect Lanausse, PR        NA-US-PR-SECT LANAUSSE          False
# 3      Urb Eugene Rice, PR      NA-US-PR-URB EUGENE RICE          False
# 4         Urb Gonzalez, PR         NA-US-PR-URB GONZALEZ          False
#
#    TaxReturnsFiled  EstimatedPopulation  TotalWages Notes
# 0              NaN                  NaN         NaN   NaN
# 1              NaN                  NaN         NaN   NaN
# 2              NaN                  NaN         NaN   NaN
# 3              NaN                  NaN         NaN   NaN
# 4              NaN                  NaN         NaN   NaN
#        RecordNumber  Zipcode ZipCodeType           City State    LocationType  \
# 81826         81832    10200    STANDARD  NEW YORK CITY    NY  NOT ACCEPTABLE
# 81827         81833    10200    STANDARD             NY    NY  NOT ACCEPTABLE
# 81828         81834    10200    STANDARD        NY CITY    NY  NOT ACCEPTABLE
# 81829         81835    10200    STANDARD            NYC    NY  NOT ACCEPTABLE
# 81830         81837     9323    MILITARY            APO    AE         PRIMARY
#
#          Lat   Long  Xaxis  Yaxis  Zaxis WorldRegion Country  \
# 81826  40.77  73.95   0.20   0.72   0.65         NaN      US
# 81827  40.77  73.95   0.20   0.72   0.65         NaN      US
# 81828  40.77  73.95   0.20   0.72   0.65         NaN      US
# 81829  40.77  73.95   0.20   0.72   0.65         NaN      US
# 81830 -44.25  33.53   0.59   0.39  -0.69         NaN      IQ
#
#             LocationText                Location  Decommisioned  \
# 81826  New York City, NY  NA-US-NY-NEW YORK CITY          False
# 81827             NY, NY             NA-US-NY-NY          False
# 81828        NY CITY, NY        NA-US-NY-NY CITY          False
# 81829            NYC, NY            NA-US-NY-NYC          False
# 81830               Iraq                   ME-IQ          False
#
#        TaxReturnsFiled  EstimatedPopulation  TotalWages Notes
# 81826              NaN                  NaN         NaN   NaN
# 81827              NaN                  NaN         NaN   NaN
# 81828              NaN                  NaN         NaN   NaN
# 81829              NaN                  NaN         NaN   NaN
# 81830              NaN                  NaN         NaN   NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81831 entries, 0 to 81830
# Data columns (total 20 columns):
# RecordNumber           81831 non-null int64
# Zipcode                81831 non-null int64
# ZipCodeType            81831 non-null object
# City                   81831 non-null object
# State                  81831 non-null object
# LocationType           81831 non-null object
# Lat                    81178 non-null float64
# Long                   81178 non-null float64
# Xaxis                  81831 non-null float64
# Yaxis                  81831 non-null float64
# Zaxis                  81831 non-null float64
# WorldRegion            334 non-null object
# Country                81831 non-null object
# LocationText           81180 non-null object
# Location               81830 non-null object
# Decommisioned          81831 non-null bool
# TaxReturnsFiled        58447 non-null float64
# EstimatedPopulation    58447 non-null float64
# TotalWages             58354 non-null float64
# Notes                  1844 non-null object
# dtypes: bool(1), float64(8), int64(2), object(9)
# memory usage: 11.9+ MB
# None

# %%
business_data = business_df[['business_id','name','attributes','city','state','categories','stars','review_count','is_open','latitude','longitude','postal_code']]
census_data = census_df[['NAME','STNAME','POPESTIMATE2017']]
census_data.columns = ['area', 'state', 'population']
zipcode_data = zipcode_df[['Zipcode','City','State','Lat','Long','Country','Location','Decommisioned']]
zipcode_data.columns = ['postal_code','city','state','lat','long','country','location','decommisioned']

# %%
display(business_data)
display(census_data)
display(zipcode_data)
# Out:
#                    business_id                                 name  \
# 0       Apn5Q_b6Nz61Tq4XzPdf9A                 Minhas Micro Brewery
# 1       AjEbIBw6ZFfln7ePHha9PA                  CK'S BBQ & Catering
# 2       O8S5hYJ1SMc8fA4QBtVujA                        La Bastringue
# 3       bFzdJJ3wp3PZssNEsyU23g                      Geico Insurance
# 4       8USyCYqpScwiNEb58Bt6CA                        Action Engine
# 5       45bWSZtniwPRiqlivpS8Og           The Coffee Bean & Tea Leaf
# 6       9A2quhZLyWk0akUetBd8hQ                       Bnc Cake House
# 7       6OuOZAok8ikONMS_T3EzXg                          Thai One On
# 8       8-NRKkPY1UiFXW20WXKiXg             Filiberto's Mexican Food
# 9       UTm5QZThPQlT35mkAcGOjg              Maggie & Stella's Gifts
# 10      KapTdGyGs7RK0c68Z6hhhg                              Sushi 8
# 11      tZnSodhPwNr4bzrwJ1CSbw           Southern Accent Restaurant
# 12      _c3ixq9jYKxhLUB0czi0ug             Original Hamburger Works
# 13      bBUMib8l6Me1ZB1_Qkezkg                Mysore Indian Cuisine
# 14      o_zDURWzgt5yM5HW_xGJsg              North Haven Barber Shop
# 15      IbTDLI02Sq50C7B-EWK1sg                  Safeway Food & Drug
# 16      r89Re4FNgVWHgBfjCVZyVw                               Harlow
# 17      hTzcHtk4-0QJnFUbkKpd5Q                          Citi Trends
# 18      UwIpS9UKsPiKAv1fiEYhqg        Nevada Title And Payday Loans
# 19      vJIuDBdu01vCA8y1fwR1OQ                           CakesbyToi
# 20      YZCHr68c5aEVHz0bkq9K2g                    Park Stone Pavers
# 21      gJ5xSt6147gkcZ9Es0WxlA                   Rally's Hamburgers
# 22      3ByGQOVgds2YEu6kzl-XEQ                             Rib Shop
# 23      5J3b7j3Fzo9ISjChmoUoUA                       Mabel's Bakery
# 24      CeuTRtwsq6w5rztGOyNMPg                             Salsitas
# 25      gsoSAb9t7Ar7Ww6O_3GuOg                   Los Toros Numero 2
# 26      guRyrKMBDkcHExGzwxSfvg          ADT Security Services, Inc.
# 27      PMDlKLd0Mxj0ngCpuUmE5Q           The Coffee Mill Restaurant
# 28      65DAbjsiws2_T600pNpWFQ                      Laurier Optical
# 29      6YC6CsXRrmPv_iwfvc9onA                     Teresas Pizzeria
# ...                        ...                                  ...
# 188563  eLExQY6_KOYaayapWNp5IQ                              NCE BBQ
# 188564  DXTsi_ZiRSsDTj3towE2GA                 Chandler Nail and Sp
# 188565  xMdkVHCYYSyw63hab0YTIg                              Homejoy
# 188566  m75vszskLJ1a14Ybco4IaA     Louis Vuitton Las Vegas Bellagio
# 188567  0zGeYN8ReYwVj27U7EHOJA                        American Cafe
# 188568  v62o0cbntlpDXYaJtO9Lmw  Fort Apache Desert Inn Self Storage
# 188569  CorrByydi35r-6SvmhYFHA                     Glammed Up Vegas
# 188570  K9ukZjvXhDjQZnrrOPqKSw                Montecristo Cigar Bar
# 188571  G8mz50lT484Ak6qP2N-whQ  Mary Brown's Famous Chicken & Tater
# 188572  GdGXb80QKTMRP7AdPHDnuw                  Breeze Daiquiri Bar
# 188573  JUygwe5d_MXCCOdk0WB30g            Steve Wynn's ShowStoppers
# 188574  eei5BWaI4IG4w_9CUzEl2g            Winter's Village Ice Rink
# 188575  Hl0uVuDXi0IiQu0Qv3uKzg                  Sugar Shack Records
# 188576  UGSM0VrExwChdINXpzJ_pw                       Beach Hardware
# 188577  kbaXNZLUyVuWbeQxH-NNKw                           Bell's BBQ
# 188578  Qh3zSqqgLS-qScpHidp7ag                  Aesthetics By Deena
# 188579  rOBczAlCZqgL-fA0wEidjA                      Bank of America
# 188580  -3bL-QmK7-qBYLmQuSekBw            Impressions Tile & Marble
# 188581  iYfHHScIrm9UooevAt-pZA            Inspirada Animal Hospital
# 188582  i3AziW_jq009bm26PLXdLA                    Vegas Auto Repair
# 188583  FxEoO2etCPrPLFOnGwV-Ww             Recharge Salon & Fitness
# 188584  jYU4Nd71giCWpLuj5JIxgg                          Aloha Nails
# 188585  Y_7sZoSLTJ-2mNZS8JS5Pg                   Toronto Yoga Mamas
# 188586  OAmRh1fSiTgtR1e0D4JsVQ    Authentic Taste Of Indian Cuisine
# 188587  5qVlB_Qpw6oHWmtzGUview             Jimmy's On-it Automotive
# 188588  sMQAZ3DkfrURFoJAyOhjEw                         Ross Massage
# 188589  6hvuCibNS4uECetHb9MCQQ                Four Seasons Boutique
# 188590  KleCXFYOmdACcQUvf6_XEg                  Walmart Supercenter
# 188591  3_fIsSxN2RBovQ_6EFtLzA      Residence Inn Charlotte Concord
# 188592  NkOvIueadjFUxeCyq_uQEw         Tito Jimy Salon and Boutique
#
#                                                attributes         city state  \
# 0       {u'BusinessParking': u'{'garage': False, 'stre...      Calgary    AB
# 1       {u'RestaurantsTableService': u'False', u'GoodF...    Henderson    NV
# 2       {u'RestaurantsTableService': u'True', u'GoodFo...     Montréal    QC
# 3                                                    None      Phoenix    AZ
# 4                {u'BusinessAcceptsCreditCards': u'True'}      Calgary    AB
# 5       {u'BusinessParking': u'{'garage': False, 'stre...      Phoenix    AZ
# 6       {u'RestaurantsPriceRange2': u'1', u'BusinessPa...      Toronto    ON
# 7       {u'Alcohol': u'none', u'RestaurantsGoodForGrou...  Mississauga    ON
# 8       {u'RestaurantsTableService': u'False', u'GoodF...     Avondale    AZ
# 9       {u'BusinessAcceptsCreditCards': u'True', u'Res...   Pittsburgh    PA
# 10      {u'RestaurantsGoodForGroups': u'True', u'Resta...      Markham    ON
# 11      {u'RestaurantsTableService': u'True', u'GoodFo...      Toronto    ON
# 12      {u'Alcohol': u'full_bar', u'HasTV': u'True', u...      Phoenix    AZ
# 13      {u'RestaurantsTableService': u'True', u'GoodFo...     Montréal    QC
# 14      {u'BusinessParking': u'{'garage': False, 'stre...      Calgary    AB
# 15      {u'BusinessAcceptsCreditCards': u'True', u'Goo...      Calgary    AB
# 16      {u'GoodForMeal': u'{'dessert': False, 'latenig...     Montréal    QC
# 17      {u'BusinessAcceptsCreditCards': u'True', u'Res...    Las Vegas    NV
# 18                                                   None    Las Vegas    NV
# 19      {u'BusinessAcceptsCreditCards': u'True', u'Bik...    Las Vegas    NV
# 20               {u'BusinessAcceptsCreditCards': u'True'}    Las Vegas    NV
# 21                                                   None    Cleveland    OH
# 22      {u'GoodForMeal': u'{'dessert': False, 'latenig...      Phoenix    AZ
# 23      {u'BusinessParking': u'{'garage': False, 'stre...      Toronto    ON
# 24      {u'GoodForMeal': u'{'dessert': False, 'latenig...      Phoenix    AZ
# 25      {u'RestaurantsGoodForGroups': u'True', u'Resta...   Monticello    IL
# 26      {u'BusinessAcceptsCreditCards': u'True', u'ByA...      Phoenix    AZ
# 27      {u'GoodForMeal': u'{'dessert': False, 'latenig...      Toronto    ON
# 28                                                   None  Mississauga    ON
# 29      {u'GoodForMeal': u'{'dessert': False, 'latenig...  Streetsboro    OH
# ...                                                   ...          ...   ...
# 188563  {u'HasTV': u'True', u'RestaurantsReservations'...      Vaughan    ON
# 188564  {u'BusinessAcceptsCreditCards': u'True', u'Res...     Chandler    AZ
# 188565           {u'BusinessAcceptsCreditCards': u'True'}      Toronto    ON
# 188566  {u'BusinessAcceptsCreditCards': u'True', u'Res...    Las Vegas    NV
# 188567  {u'GoodForMeal': u'{'dessert': False, 'latenig...    Las Vegas    NV
# 188568           {u'BusinessAcceptsCreditCards': u'True'}    Las Vegas    NV
# 188569  {u'BusinessParking': u'{'garage': False, 'stre...    Las Vegas    NV
# 188570  {u'WheelchairAccessible': u'True', u'BusinessP...    Las Vegas    NV
# 188571  {u'RestaurantsTableService': u'False', u'GoodF...   North York    ON
# 188572  {u'DogsAllowed': u'True', u'Alcohol': u'full_b...    Las Vegas    NV
# 188573                         {u'GoodForKids': u'False'}    Las Vegas    NV
# 188574  {u'RestaurantsGoodForGroups': u'True', u'Resta...    Henderson    NV
# 188575  {u'BusinessAcceptsCreditCards': u'True', u'Res...      Madison    WI
# 188576  {u'BusinessAcceptsCreditCards': u'True', u'Res...      Toronto    ON
# 188577  {u'Alcohol': u'beer_and_wine', u'HasTV': u'Tru...    Henderson    NV
# 188578                                               None    Henderson    NV
# 188579  {u'BusinessAcceptsCreditCards': u'True', u'ByA...    Charlotte    NC
# 188580  {u'BusinessAcceptsCreditCards': u'True', u'ByA...    Las Vegas    NV
# 188581                                               None    Henderson    NV
# 188582           {u'BusinessAcceptsCreditCards': u'True'}    Las Vegas    NV
# 188583  {u'BusinessParking': u'{'garage': False, 'stre...    Las Vegas    NV
# 188584  {u'BusinessAcceptsCreditCards': u'True', u'Res...    Las Vegas    NV
# 188585  {u'GoodForKids': u'True', u'DogsAllowed': u'Fa...      Toronto    ON
# 188586                               {u'Caters': u'True'}      Toronto    ON
# 188587                                               None   Pittsburgh    PA
# 188588  {u'AcceptsInsurance': u'False', u'ByAppointmen...   Pittsburgh    PA
# 188589                                               None   Pittsburgh    PA
# 188590  {u'BusinessParking': u'{'garage': False, 'stre...      Concord    NC
# 188591  {u'BusinessAcceptsCreditCards': u'True', u'Res...      Concord    NC
# 188592  {u'BusinessParking': u'{'garage': False, 'stre...    Las Vegas    NV
#
#                                                categories  stars  \
# 0       Tours, Breweries, Pizza, Restaurants, Food, Ho...    4.0
# 1       Chicken Wings, Burgers, Caterers, Street Vendo...    4.5
# 2       Breakfast & Brunch, Restaurants, French, Sandw...    4.0
# 3                           Insurance, Financial Services    1.5
# 4       Home & Garden, Nurseries & Gardening, Shopping...    2.0
# 5                                      Coffee & Tea, Food    4.0
# 6                                          Food, Bakeries    4.0
# 7                                       Restaurants, Thai    2.0
# 8                                    Mexican, Restaurants    2.5
# 9                   Flowers & Gifts, Gift Shops, Shopping    3.5
# 10                                  Restaurants, Japanese    1.5
# 11                    Cajun/Creole, Southern, Restaurants    4.0
# 12      Bars, Sports Bars, Dive Bars, Burgers, Nightli...    4.0
# 13         Restaurants, Pakistani, Indian, Middle Eastern    3.5
# 14                                 Beauty & Spas, Barbers    4.5
# 15                         Delis, Restaurants, Sandwiches    2.5
# 16      Nightlife, Bars, American (Traditional), Tapas...    3.5
# 17                   Shopping, Fashion, Department Stores    4.0
# 18      Financial Services, Check Cashing/Pay-day Loan...    1.0
# 19      American (Traditional), Food, Bakeries, Restau...    1.5
# 20      Home Services, Masonry/Concrete, Professional ...    5.0
# 21                        Fast Food, Burgers, Restaurants    3.0
# 22      Nightlife, Bars, American (Traditional), Sport...    2.5
# 23                           Food, Bakeries, Coffee & Tea    4.0
# 24                                   Mexican, Restaurants    2.5
# 25                                   Mexican, Restaurants    3.5
# 26       Home Services, Home Automation, Security Systems    1.0
# 27        Restaurants, Food, Canadian (New), Coffee & Tea    3.5
# 28      Optometrists, Shopping, Eyewear & Opticians, H...    1.0
# 29                                     Pizza, Restaurants    3.0
# ...                                                   ...    ...
# 188563                     Barbeque, Restaurants, Chinese    3.5
# 188564                         Nail Salons, Beauty & Spas    2.5
# 188565  Local Services, Professional Services, Carpet ...    3.5
# 188566  Eyewear & Opticians, Leather Goods, Shopping, ...    4.0
# 188567         Delis, Restaurants, American (Traditional)    2.5
# 188568                       Self Storage, Local Services    4.5
# 188569  Hair Stylists, Hair Extensions, Hair Salons, B...    5.0
# 188570  Nightlife, Bars, Shopping, Tobacco Shops, Cock...    4.5
# 188571              Chicken Wings, Fast Food, Restaurants    3.0
# 188572           Beer Bar, Cocktail Bars, Nightlife, Bars    4.0
# 188573              Performing Arts, Arts & Entertainment    4.0
# 188574  Active Life, Arts & Entertainment, Nightlife, ...    3.5
# 188575  Music & DVDs, Books, Mags, Music & Video, Shop...    2.5
# 188576           Shopping, Hardware Stores, Home & Garden    4.5
# 188577  American (Traditional), American (New), Restau...    4.0
# 188578  Hair Removal, Eyebrow Services, Beauty & Spas,...    5.0
# 188579  Banks & Credit Unions, Financial Services, Rea...    2.0
# 188580  Kitchen & Bath, Building Supplies, Home Servic...    4.5
# 188581  Pet Groomers, Pets, Veterinarians, Pet Sitting...    4.5
# 188582  Automotive, Body Shops, Auto Repair, Oil Chang...    4.5
# 188583  Beauty & Spas, Nail Salons, Active Life, Gyms,...    4.5
# 188584  Beauty & Spas, Nail Salons, Hair Removal, Waxi...    3.5
# 188585  Massage, Health & Medical, Yoga, Doulas, Activ...    5.0
# 188586  Restaurants, Indian, Caterers, Event Planning ...    3.0
# 188587          Auto Repair, Used Car Dealers, Automotive    3.0
# 188588        Skin Care, Beauty & Spas, Day Spas, Massage    2.5
# 188589  Fashion, Women's Clothing, Accessories, Bridal...    2.0
# 188590  Mobile Phones, Shopping, Department Stores, Fo...    3.0
# 188591  Event Planning & Services, Hotels & Travel, Ho...    4.0
# 188592  Makeup Artists, Men's Clothing, Swimwear, Shop...    4.0
#
#         review_count  is_open   latitude   longitude postal_code
# 0                 24        1  51.091813 -114.031675     T2E 6L6
# 1                  3        0  35.960734 -114.939821       89002
# 2                  5        0  45.540503  -73.599300     H2G 1K7
# 3                  8        1  33.449999 -112.076979       85003
# 4                  4        1  51.035591 -114.027366     T2H 0N5
# 5                 63        1  33.671375 -112.030017       85024
# 6                  7        0  43.664378  -79.414424     M6G 1K8
# 7                  7        1  43.712946  -79.632763     L4T 1A8
# 8                 40        1  33.448106 -112.341302       85323
# 9                  3        1  40.441421  -79.956457       15213
# 10                12        0  43.862484  -79.306960     L3R 1M5
# 11               146        0  43.664125  -79.411886     M6G 2L7
# 12               277        1  33.479807 -112.091188       85007
# 13                19        1  45.518036  -73.582174     H2W 1Z3
# 14                 3        1  51.091857 -114.094625         T2K
# 15                 4        1  51.042469 -114.139574     T3C 1S2
# 16                12        0  45.507699  -73.553407     H2Y 3B3
# 17                 4        1  36.178348 -115.176916       89106
# 18                 4        1  36.188386 -115.186124       89106
# 19                 3        0  36.192284 -115.159272       89106
# 20                20        1  36.260816 -115.171130       89031
# 21                 5        1  41.499989  -81.666375       44115
# 22                 3        1  33.495298 -112.236076       85033
# 23                23        1  43.681328  -79.427884     M6C 1B5
# 24                14        1  33.479671 -112.225173       85033
# 25                 6        0  40.009328  -88.576386       61856
# 26                 4        1  33.431665 -112.102959       85001
# 27                25        0  43.670885  -79.392379     M5R 3K5
# 28                 3        1  43.609269  -79.699035     L5V 2X8
# 29                11        1  41.243783  -81.356661       44241
# ...              ...      ...        ...         ...         ...
# 188563            13        0  43.797454  -79.425888     L4J 2L1
# 188564             6        1  33.260503 -111.856951       85248
# 188565             9        0  43.653226  -79.383184     M5R 3V5
# 188566            51        1  36.113956 -115.173910       89109
# 188567             7        1  36.131516 -115.164565       89109
# 188568            18        1  36.128235 -115.298251       89117
# 188569            59        1  36.128561 -115.171130       89109
# 188570           108        1  36.116775 -115.175368       89109
# 188571            20        1  43.718455  -79.455328     M6A 2T2
# 188572             5        1  36.119650 -115.171428       89109
# 188573           109        0  36.126595 -115.165365       89109
# 188574            28        0  36.022406 -115.091960       89052
# 188575             6        1  43.093412  -89.348454       53704
# 188576             3        1  43.670761  -79.295926     M4E 1E8
# 188577           447        1  35.993777 -115.101582       89052
# 188578             5        1  35.990302 -115.102120       89052
# 188579             3        1  35.163280  -80.739262       28227
# 188580             6        1  36.105866 -115.206215       89103
# 188581            54        1  35.941616 -115.118942       89044
# 188582             9        1  36.120743 -115.192017       89103
# 188583            20        1  36.114304 -115.193871       89103
# 188584            76        1  36.115367 -115.226848       89103
# 188585            14        1  43.664756  -79.324295     M4L 1C9
# 188586             3        0  43.628947  -79.394420         M5V
# 188587             4        1  40.524391  -80.004396       15237
# 188588             9        0  40.551152  -80.021213       15237
# 188589             5        1  40.534242  -80.019556       15237
# 188590            26        1  35.378669  -80.724733       28027
# 188591            19        1  35.364366  -80.703454       28027
# 188592             8        1  36.118697 -115.154269       89169
#
# [188593 rows x 12 columns]
#                                area    state  population
# 0                           Alabama  Alabama     4874747
# 1                    Abbeville city  Alabama        2567
# 2                   Adamsville city  Alabama        4347
# 3                      Addison town  Alabama         728
# 4                        Akron town  Alabama         332
# 5                    Alabaster city  Alabama       33202
# 6                  Albertville city  Alabama       21392
# 7               Alexander City city  Alabama       14595
# 8                   Aliceville city  Alabama        2335
# 9                      Allgood town  Alabama         624
# 10                     Altoona town  Alabama         917
# 11                   Andalusia city  Alabama        8787
# 12                    Anderson town  Alabama         276
# 13                    Anniston city  Alabama       21770
# 14                        Arab city  Alabama        8284
# 15                     Ardmore town  Alabama        1398
# 16                        Argo town  Alabama        4268
# 17                      Ariton town  Alabama         739
# 18                       Arley town  Alabama         346
# 19                     Ashford town  Alabama        2144
# 20                     Ashland town  Alabama        1932
# 21                    Ashville city  Alabama        2291
# 22                      Athens city  Alabama       25616
# 23                      Atmore city  Alabama        9890
# 24                     Attalla city  Alabama        5827
# 25                      Auburn city  Alabama       63973
# 26                Autaugaville town  Alabama         855
# 27                        Avon town  Alabama         514
# 28                      Babbie town  Alabama         599
# 29                   Baileyton town  Alabama         622
# ...                             ...      ...         ...
# 81516               Sublette County  Wyoming        9799
# 81517                Big Piney town  Wyoming         524
# 81518                Marbleton town  Wyoming        1111
# 81519                 Pinedale town  Wyoming        1890
# 81520    Balance of Sublette County  Wyoming        6274
# 81521             Sweetwater County  Wyoming       43534
# 81522                  Bairoil town  Wyoming         100
# 81523                  Granger town  Wyoming         133
# 81524              Green River city  Wyoming       12070
# 81525             Rock Springs city  Wyoming       23350
# 81526                 Superior town  Wyoming         316
# 81527                Wamsutter town  Wyoming         484
# 81528  Balance of Sweetwater County  Wyoming        7081
# 81529                  Teton County  Wyoming       23265
# 81530                  Jackson town  Wyoming       10532
# 81531       Balance of Teton County  Wyoming       12733
# 81532                  Uinta County  Wyoming       20495
# 81533               Bear River town  Wyoming         518
# 81534                 Evanston city  Wyoming       11866
# 81535                    Lyman town  Wyoming        2067
# 81536            Mountain View town  Wyoming        1261
# 81537       Balance of Uinta County  Wyoming        4783
# 81538               Washakie County  Wyoming        8064
# 81539                Ten Sleep town  Wyoming         257
# 81540                  Worland city  Wyoming        5189
# 81541    Balance of Washakie County  Wyoming        2618
# 81542                 Weston County  Wyoming        6927
# 81543                Newcastle city  Wyoming        3389
# 81544                    Upton town  Wyoming        1060
# 81545      Balance of Weston County  Wyoming        2478
#
# [81546 rows x 3 columns]
#        postal_code                      city state    lat    long country  \
# 0              704               PARC PARQUE    PR  17.96  -66.22      US
# 1              704       PASEO COSTA DEL SUR    PR  17.96  -66.22      US
# 2              704             SECT LANAUSSE    PR  17.96  -66.22      US
# 3              704           URB EUGENE RICE    PR  17.96  -66.22      US
# 4              704              URB GONZALEZ    PR  17.96  -66.22      US
# 5              704            URB LA FABRICA    PR  17.96  -66.22      US
# 6              704         URB MONTE SORIA 2    PR  17.96  -66.22      US
# 7              704          VILLAS DEL COQUI    PR  17.96  -66.22      US
# 8              705                  AIBONITO    PR  18.14  -66.26      US
# 9              705              BDA SAN LUIS    PR  18.14  -66.26      US
# 10             705                 BO LLANOS    PR  18.14  -66.26      US
# 11             705        BRISAS DE AIBONITO    PR  18.14  -66.26      US
# 12             705  COLINAS DE SAN FRANCISCO    PR  18.14  -66.26      US
# 13             705             EST DEL LLANO    PR  18.14  -66.26      US
# 14             705           EXT BELLA VISTA    PR  18.14  -66.26      US
# 15             705              EXT SAN LUIS    PR  18.14  -66.26      US
# 16             705         EXT VILLA ROSALES    PR  18.14  -66.26      US
# 17             705              REPTO ROBLES    PR  18.14  -66.26      US
# 18             705           URB BELLA VISTA    PR  18.14  -66.26      US
# 19             705           URB BUENA VISTA    PR  18.14  -66.26      US
# 20             705         URB GOLDEN VLG IV    PR  18.14  -66.26      US
# 21             705        URB LA PROVIDENCIA    PR  18.14  -66.26      US
# 22             705          VILLA DE LA ROSA    PR  18.14  -66.26      US
# 23             705             VILLA ROSALES    PR  18.14  -66.26      US
# 24             705          VILLAS DEL COQUI    PR  18.14  -66.26      US
# 25             610                    ANASCO    PR  18.28  -67.14      US
# 26             610          BRISAS DE ANASCO    PR  18.28  -67.14      US
# 27             610        EST DE VALLE VERDE    PR  18.28  -67.14      US
# 28             610            JARD DE ANASCO    PR  18.28  -67.14      US
# 29             610           PASEO DEL VALLE    PR  18.28  -67.14      US
# ...            ...                       ...   ...    ...     ...     ...
# 81801        98460                    TACOMA    WA  47.25 -122.44      US
# 81802        98460          WA STATE LOTTERY    WA  47.25 -122.44      US
# 81803        98477           WEYERHAEUSER CO    WA  47.25 -122.44      US
# 81804        98477                    TACOMA    WA  47.25 -122.44      US
# 81805        98492                  LAKEWOOD    WA  47.12 -122.55      US
# 81806        98492                    TACOMA    WA  47.12 -122.55      US
# 81807        98667                     ABMPS    WA  45.63 -122.66      US
# 81808        98667                 VANCOUVER    WA  45.63 -122.66      US
# 81809        98929             GOOSE PRAIRIE    WA  46.74 -121.14      US
# 81810        98929                    NACHES    WA  46.74 -121.14      US
# 81811        99165                   PULLMAN    WA  46.73 -117.17      US
# 81812        99779                       TOK    AK  63.13 -142.53      US
# 81813         9300                       APO    AE    NaN     NaN      IQ
# 81814         9303                       APO    AE    NaN     NaN      BH
# 81815         9379                       FPO    AE    NaN     NaN      BH
# 81816        96400                       APO    AP    NaN     NaN      TH
# 81817        96547                       APO    AP    NaN     NaN      TH
# 81818        34009                       APO    AA    NaN     NaN      GY
# 81819        34010                       APO    AA    NaN     NaN      HN
# 81820        34001                       APO    AA    NaN     NaN      NI
# 81821        34071                       APO    AA    NaN     NaN      PY
# 81822        97475               SPRINGFIELD    OR  44.05 -123.02      US
# 81823         9848                       APO    AE    NaN     NaN      US
# 81824        10200                  NEW YORK    NY  40.77   73.95      US
# 81825        10200                 MANHATTAN    NY  40.77   73.95      US
# 81826        10200             NEW YORK CITY    NY  40.77   73.95      US
# 81827        10200                        NY    NY  40.77   73.95      US
# 81828        10200                   NY CITY    NY  40.77   73.95      US
# 81829        10200                       NYC    NY  40.77   73.95      US
# 81830         9323                       APO    AE -44.25   33.53      IQ
#
#                                       location  decommisioned
# 0                         NA-US-PR-PARC PARQUE          False
# 1                 NA-US-PR-PASEO COSTA DEL SUR          False
# 2                       NA-US-PR-SECT LANAUSSE          False
# 3                     NA-US-PR-URB EUGENE RICE          False
# 4                        NA-US-PR-URB GONZALEZ          False
# 5                      NA-US-PR-URB LA FABRICA          False
# 6                   NA-US-PR-URB MONTE SORIA 2          False
# 7                    NA-US-PR-VILLAS DEL COQUI          False
# 8                            NA-US-PR-AIBONITO          False
# 9                        NA-US-PR-BDA SAN LUIS          False
# 10                          NA-US-PR-BO LLANOS          False
# 11                 NA-US-PR-BRISAS DE AIBONITO          False
# 12           NA-US-PR-COLINAS DE SAN FRANCISCO          False
# 13                      NA-US-PR-EST DEL LLANO          False
# 14                    NA-US-PR-EXT BELLA VISTA          False
# 15                       NA-US-PR-EXT SAN LUIS          False
# 16                  NA-US-PR-EXT VILLA ROSALES          False
# 17                       NA-US-PR-REPTO ROBLES          False
# 18                    NA-US-PR-URB BELLA VISTA          False
# 19                    NA-US-PR-URB BUENA VISTA          False
# 20                  NA-US-PR-URB GOLDEN VLG IV          False
# 21                 NA-US-PR-URB LA PROVIDENCIA          False
# 22                   NA-US-PR-VILLA DE LA ROSA          False
# 23                      NA-US-PR-VILLA ROSALES          False
# 24                   NA-US-PR-VILLAS DEL COQUI          False
# 25                             NA-US-PR-ANASCO          False
# 26                   NA-US-PR-BRISAS DE ANASCO          False
# 27                 NA-US-PR-EST DE VALLE VERDE          False
# 28                     NA-US-PR-JARD DE ANASCO          False
# 29                    NA-US-PR-PASEO DEL VALLE          False
# ...                                        ...            ...
# 81801                          NA-US-WA-TACOMA           True
# 81802                NA-US-WA-WA STATE LOTTERY           True
# 81803                 NA-US-WA-WEYERHAEUSER CO           True
# 81804                          NA-US-WA-TACOMA           True
# 81805                        NA-US-WA-LAKEWOOD           True
# 81806                          NA-US-WA-TACOMA           True
# 81807                           NA-US-WA-ABMPS           True
# 81808                       NA-US-WA-VANCOUVER           True
# 81809                   NA-US-WA-GOOSE PRAIRIE           True
# 81810                          NA-US-WA-NACHES           True
# 81811                         NA-US-WA-PULLMAN           True
# 81812                             NA-US-AK-TOK           True
# 81813                         ME-IQ-CAMP BUCCA           True
# 81814                        ME-BH-MCA BAHRAIN           True
# 81815       ME-BH-FMC BAH CONTINGENCY - MANAMA           True
# 81816                 AS-TH-COBRA GOLD BANGKOK           True
# 81817                            AS-TH-BANGKOK           True
# 81818                 SA-GY-NEW HORIZON-GUYANA           True
# 81819  CA-HN-NEW HORIZON  LA CEIBA - COMAYAGUA           True
# 81820      CA-NI-JTF JUNTOS  PODEMOS BASE CAMP           True
# 81821         SA-PY-JTF NEW HORIZON-CONCEPCION           True
# 81822                     NA-US-OR-SPRINGFIELD          False
# 81823                                      NaN          False
# 81824                        NA-US-NY-NEW YORK          False
# 81825                       NA-US-NY-MANHATTAN          False
# 81826                   NA-US-NY-NEW YORK CITY          False
# 81827                              NA-US-NY-NY          False
# 81828                         NA-US-NY-NY CITY          False
# 81829                             NA-US-NY-NYC          False
# 81830                                    ME-IQ          False
#
# [81831 rows x 8 columns]

# %%
states = business_data['state'].drop_duplicates()
census_states = census_data['state'].drop_duplicates()
# List of 51 states
valid_states= ['AL','AK','AZ','AR','CA','CO','CT','DE','DC','FL','GA','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY']
# Create a lookup table for states and their abbreviation
states_lookup = pd.DataFrame(zip(census_states,valid_states), columns=['state','abbrv'])
# Out:
#                    state abbrv
# 0                Alabama    AL
# 1                 Alaska    AK
# 2                Arizona    AZ
# 3               Arkansas    AR
# 4             California    CA
# 5               Colorado    CO
# 6            Connecticut    CT
# 7               Delaware    DE
# 8   District of Columbia    DC
# 9                Florida    FL
# 10               Georgia    GA
# 11                Hawaii    HI
# 12                 Idaho    ID
# 13              Illinois    IL
# 14               Indiana    IN
# 15                  Iowa    IA
# 16                Kansas    KS
# 17              Kentucky    KY
# 18             Louisiana    LA
# 19                 Maine    ME
# 20              Maryland    MD
# 21         Massachusetts    MA
# 22              Michigan    MI
# 23             Minnesota    MN
# 24           Mississippi    MS
# 25              Missouri    MO
# 26               Montana    MT
# 27              Nebraska    NE
# 28                Nevada    NV
# 29         New Hampshire    NH
# 30            New Jersey    NJ
# 31            New Mexico    NM
# 32              New York    NY
# 33        North Carolina    NC
# 34          North Dakota    ND
# 35                  Ohio    OH
# 36              Oklahoma    OK
# 37                Oregon    OR
# 38          Pennsylvania    PA
# 39          Rhode Island    RI
# 40        South Carolina    SC
# 41          South Dakota    SD
# 42             Tennessee    TN
# 43                 Texas    TX
# 44                  Utah    UT
# 45               Vermont    VT
# 46              Virginia    VA
# 47            Washington    WA
# 48         West Virginia    WV
# 49             Wisconsin    WI
# 50               Wyoming    WY

# %%
# Add abbreviation to census_data for future use
census_data = census_data.merge(states_lookup, on='state')

# %%
# Convert 'area' to title case
census_data.loc[:,'area'] = census_data['area'].apply(lambda c: c.title())
# Remove 'city' and 'town', keep only the area name
census_data.area = census_data.area.str.replace(r'( Town$)|( City And Borough)|( Borough)','')
# Out:
#                                  area         state  population abbrv
# 10734                   Ross Township      Illinois        1476    IL
# 10736        Balance Of Ross Township      Illinois         230    IL
# 13933                   Ross Township      Illinois          67    IL
# 14710                   Ross Township      Illinois        1536    IL
# 14712        Balance Of Ross Township      Illinois         283    IL
# 14717             South Ross Township      Illinois        1023    IL
# 14720  Balance Of South Ross Township      Illinois         526    IL
# 16292                   Ross Township       Indiana        2855    IN
# 16294        Balance Of Ross Township       Indiana        1228    IN
# 17561                   Ross Township       Indiana       47701    IN
# 17565        Balance Of Ross Township       Indiana         211    IN
# 22318                   Ross Township        Kansas         730    KS
# 22321        Balance Of Ross Township        Kansas         485    KS
# 24190                   Ross Township        Kansas         933    KS
# 24192        Balance Of Ross Township        Kansas          87    KS
# 30755                   Ross Township      Michigan        4922    MI
# 30757        Balance Of Ross Township      Michigan        4053    MI
# 36909                   Ross Township     Minnesota         411    MN
# 52938                   Ross Township  North Dakota          54    ND
# 55387                   Ross Township          Ohio        8821    OH
# 55389        Balance Of Ross Township          Ohio        8272    OH
# 56510                   Ross Township          Ohio         776    OH
# 56512        Balance Of Ross Township          Ohio         776    OH
# 57123                   Ross Township          Ohio         687    OH
# 62896                   Ross Township  Pennsylvania       30612    PA
# 65605                   Ross Township  Pennsylvania        2905    PA
# 65883                   Ross Township  Pennsylvania        5805    PA
#                    business_id                    name  \
# 9487    nL8_8Icehnn07NSmkToNuA                 hhgregg
# 19110   sgRHJZU05UfZGRReGuXoCg          My Oreck Store
# 35195   7Qpn2DvgIUpOJQdI4DXETQ            Panera Bread
# 104431  MvbWrmRp7OZYeZ_XFNa2BQ              EZ Storage
# 161820  kPwYdRKp1-W1-tUR8iylxw        Aladdin's Eatery
# 171737  7ADjU1ZmRfUeMebjbYU3kw  The Cheesecake Factory
# 172284  B-RfICsfrTPKwv88HAg1sA            Troy Granite
# 180615  ljroU4H3m4UZsHzOiaR2QA        Guardian Storage
#
#                                                attributes           city  \
# 9487    {u'BusinessAcceptsCreditCards': u'True', u'Bus...  Ross Township
# 19110                                                None  Ross Township
# 35195   {u'RestaurantsTableService': u'False', u'GoodF...  Ross Township
# 104431           {u'BusinessAcceptsCreditCards': u'True'}  Ross Township
# 161820  {u'RestaurantsTableService': u'True', u'GoodFo...  Ross Township
# 171737  {u'Alcohol': u'full_bar', u'HasTV': u'True', u...  Ross Township
# 172284  {u'BusinessParking': u'{'garage': False, 'stre...  Ross Township
# 180615  {u'BusinessAcceptsCreditCards': u'True', u'Bus...  Ross Township
#
#        state                                         categories  stars  \
# 9487      PA                              Electronics, Shopping    2.0
# 19110     PA  Shopping, Appliances & Repair, Home & Garden, ...    3.5
# 35195     PA  Breakfast & Brunch, Food, Soup, Sandwiches, Re...    3.0
# 104431    PA                       Self Storage, Local Services    5.0
# 161820    PA  Desserts, Mediterranean, Middle Eastern, Resta...    4.0
# 171737    PA  American (Traditional), American (New), Seafoo...    3.5
# 172284    PA  Home Services, Flooring, Home & Garden, Cabine...    4.0
# 180615    PA                       Local Services, Self Storage    5.0
#
#         review_count  is_open   latitude  longitude postal_code
# 9487               6        1  40.539817 -80.012528       15237
# 19110              3        1  40.529697 -80.010085       15237
# 35195             10        1  40.537139 -80.013116       15237
# 104431             9        1  40.547394 -80.007888       15237
# 161820            74        1  40.530338 -80.010495       15237
# 171737           132        1  40.544559 -80.008739       15237
# 172284            10        1  40.533935 -80.054861       15237
# 180615             3        1  40.544554 -80.013378       15237

# %%
census_data = census_data.drop_duplicates()

# %%
# Fix one record with incorrect state name
business_data.loc[business_data.state=='TAM','state'] = 'NV'

# Remove businesses that are not in USA and those are closed
business_data = business_data[business_data.state.isin(valid_states) & business_data.is_open == 1]

# Remove businesses that are not food businesses
food_categories = ['Food','Coffee','Tea','Bars','Restaurants','Cafes','Salad','Delis','Bakeries','Desserts']
food_business = business_data.loc[business_data['categories'].fillna('').str.contains('|'.join(food_categories))]

# Create a function to check if any empty string exists
def is_empty(df, col):
    return df[col] == ''

# Check if city has empty string
display(food_business[is_empty(food_business, 'city')])
# Change to correct city name
food_business.loc[food_business['business_id'] == 'uM-zXJpjD9SIB2dnRP1Hsg','city'] = 'Raleigh'
display(food_business[is_empty(food_business, 'city')])
# Check if state has empty string
display(food_business[is_empty(food_business, 'state')])
# Check if business name has empty string
display(food_business[is_empty(food_business, 'name')])
# Out:
# /Users/supeng-wen/miniconda2/envs/cp1/lib/python2.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                    business_id        name  \
# 111036  uM-zXJpjD9SIB2dnRP1Hsg  Char-Grill
#
#                                                attributes city state  \
# 111036  {u'RestaurantsTableService': u'False', u'GoodF...         NC
#
#                                           categories  stars  review_count  \
# 111036  Burgers, American (Traditional), Restaurants    2.5            21
#
#         is_open   latitude  longitude postal_code
# 111036        1  35.873847 -78.790256       27623
# Empty DataFrame
# Columns: [business_id, name, attributes, city, state, categories, stars, review_count, is_open, latitude, longitude, postal_code]
# Index: []
# Empty DataFrame
# Columns: [business_id, name, attributes, city, state, categories, stars, review_count, is_open, latitude, longitude, postal_code]
# Index: []
# Empty DataFrame
# Columns: [business_id, name, attributes, city, state, categories, stars, review_count, is_open, latitude, longitude, postal_code]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33958 entries, 5 to 188590
# Data columns (total 12 columns):
# business_id     33958 non-null object
# name            33958 non-null object
# attributes      33235 non-null object
# city            33958 non-null object
# state           33958 non-null object
# categories      33958 non-null object
# stars           33958 non-null float64
# review_count    33958 non-null int64
# is_open         33958 non-null int64
# latitude        33957 non-null float64
# longitude       33958 non-null float64
# postal_code     33958 non-null object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 3.4+ MB
# None

# %%
# Remove zipcodes that are decommisioned and out of US
zipcode_data = zipcode_data.loc[zipcode_data['country'] == 'US']
zipcode_data = zipcode_data.loc[zipcode_data['decommisioned'] == False]
# Capitalize first character
zipcode_data.loc[:,'city'] = zipcode_data['city'].apply(lambda c: c.title())
# Change 'postal_code' dtype to string(object)
zipcode_data.loc[:,'postal_code'] = zipcode_data['postal_code'].apply(lambda x: str(x))
# Create a lookup dataframe with zipcode and state
zipcode_state = zipcode_data[['postal_code','state']].drop_duplicates()
display(zipcode_data.info())
display(zipcode_state)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80334 entries, 0 to 81829
# Data columns (total 8 columns):
# postal_code      80334 non-null object
# city             80334 non-null object
# state            80334 non-null object
# lat              80102 non-null float64
# long             80102 non-null float64
# country          80334 non-null object
# location         80333 non-null object
# decommisioned    80334 non-null bool
# dtypes: bool(1), float64(2), object(5)
# memory usage: 5.0+ MB
# None
#       postal_code state
# 0             704    PR
# 8             705    PR
# 25            610    PR
# 32            611    PR
# 33            612    PR
# 56            601    PR
# 60            631    PR
# 62            602    PR
# 68            603    PR
# 101           604    PR
# 103           605    PR
# 104           703    PR
# 112          7093    NJ
# 114          7675    NJ
# 118          7677    NJ
# 121          7885    NJ
# 122          7981    NJ
# 123          7999    NJ
# 124          8888    NJ
# 125          8889    NJ
# 128          7095    NJ
# 129          7481    NJ
# 130         10451    NY
# 131         10452    NY
# 135         10453    NY
# 136         10454    NY
# 138         10455    NY
# 140         10456    NY
# 142         10457    NY
# 143         10458    NY
# ...           ...   ...
# 80642       96669    AP
# 80643       96670    AP
# 80644       96671    AP
# 80645       96672    AP
# 80646       96673    AP
# 80647       96674    AP
# 80648       96675    AP
# 80649       96677    AP
# 80650       96678    AP
# 80651       96679    AP
# 80652       96681    AP
# 80653       96682    AP
# 80654       96683    AP
# 80655       96686    AP
# 80656       96687    AP
# 80657       96698    AP
# 80658       56901    DC
# 80661       56902    DC
# 80664       56904    DC
# 80667       56915    DC
# 80670       56920    DC
# 80673       56933    DC
# 80676       56944    DC
# 80679       56945    DC
# 80682       56950    DC
# 80686       56965    DC
# 80687       56972    DC
# 81822       97475    OR
# 81823        9848    AE
# 81824       10200    NY
#
# [41547 rows x 2 columns]

# %%
# Merge food_business with zipcode_state 
food_business = food_business.merge(zipcode_state, how='left', on='postal_code')

# %%
# Convert 'city' to title case
food_business.loc[:,'city'] = food_business['city'].apply(lambda c: c.title())
# Fix incorrect records
state_to_replace = {'AL':'AZ','NC':'SC','OH':'KY'}
zipcode_to_replace = {'93013':'89119'}
food_business[food_business['state_x'] != food_business['state_y']] = food_business[food_business['state_x'] != food_business['state_y']].replace({'state_x':state_to_replace,'postal_code':zipcode_to_replace})

food_business.loc[food_business['business_id'] == '23hNsQz1XYDv5qGkHsM5gQ','state_x'] = 'NV'
food_business.loc[food_business['business_id'] == 'WA5c3d6rhjioD3Ri4nCX1A','city'] = 'Bracey'
food_business.loc[food_business['business_id'] == 'WA5c3d6rhjioD3Ri4nCX1A','postal_code'] = '23919'
food_business.loc[food_business['business_id'] == '0gwjwRbUGrHnJdoDwYF9lA','city'] = 'Levelland'
food_business.loc[food_business['business_id'] == '0gwjwRbUGrHnJdoDwYF9lA','state_x'] = 'TX'
food_business.loc[food_business['business_id'] == 'CzmyMl4jnlyQYVaf3YmDYQ','city'] = 'Baltimore'
food_business.loc[food_business['business_id'] == 'CzmyMl4jnlyQYVaf3YmDYQ','state_x'] = 'MD'
food_business.loc[food_business['business_id'] == 'KKMzRG_P7Kd4LJkqqxXyPg','state_x'] = 'NC'
oh_list = ['w8_gMZb2TyfkzslI4XMOew','6wWxJbZREP46AFHwFvsQlw','ybButD4cr1Zpn-Abwsrehg']
food_business.loc[food_business['business_id'].isin(oh_list),'state_x'] = 'OH'
food_business.loc[food_business['business_id'] == 'G59Wxm8eicbgOBxdZhxhVQ','city'] = 'Harrisburg'
food_business.loc[food_business['business_id'] == 'qYcQxgd3YlyoQtnjxm4x8w','city'] = 'Litchfield Park'
city_pitts = ['yKJCTTGgUr8IHyQDk6NKfA','wf3y8-wNJ5pIlxwMaU0h6Q','uxRBduJIbkY5FFfJCVVdVQ','err0FvoRGGSqORd8WRtppA','2To5KDQepjSUpdA5oPPRog','4LLNNwkveVoH1m6z_9jLGQ','txF4WKY3P2hF3i6VCRD8YA']
food_business.loc[food_business['business_id'].isin(city_pitts) ,'city'] = 'Pittsburgh'
food_business.loc[food_business['business_id'] == 'ulLQMYF2gGIWZg9Yhybz0w','city'] = 'Ross Township'
food_business.loc[food_business['business_id'] == '110iMPMPEEjFlf8HKVq84g','city'] = 'Charlotte'
food_business.loc[food_business['business_id'] == '1jdE-PeiQHvL8165vebWrw','city'] = 'Charlotte'
food_business.loc[food_business['business_id'] == 'NiYCc7bhbQXftDQPON1aaQ','city'] = 'Henderson'
food_business.loc[food_business['business_id'] == 'pgpnvPd3mWxI0O9WYUeLnA','city'] = 'Glendale'
food_business.loc[food_business['business_id'] == 'BbVvT3E_y9TZpzTtIpXNkw','city'] = 'Scottsdale'
food_business.loc[food_business['business_id'] == '0Zu6KcjFJjBpCOjiOa2HvQ','city'] = 'Scottsdale'
food_business.loc[food_business['business_id'] == 'NC3Dw2kXxIwcnPD4Q8FgJA','city'] = 'Hermitage'
food_business.loc[food_business['business_id'] == 'svU7GceMV2PsJe6MLSJWIA','city'] = 'Mesa'
food_business.loc[food_business['business_id'] == 'a0imQZn-utjU8kyIfEdwLg','city'] = 'Mint Hill'
food_business.loc[food_business['business_id'] == 'DIdvV0HZUMZWiYg4OXyGJg','city'] = 'Robinson Township'
food_business.loc[food_business['business_id'] == 'KAJAsjVhYUPb6b_yodVqvA','city'] = 'Cleveland'
food_business.loc[food_business['business_id'] == 'tzUwZKhtDX7QixvXex-wZw','city'] = 'Canonsburg'
food_business.loc[food_business['business_id'] == 'SRrW_Vz38dY36cWGZDC7Nw','city'] = 'Davidson'
food_business.loc[food_business['business_id'] == 'iUPRmBfFZe4oz78R9m_zSw','city'] = 'Belleville'
food_business.loc[food_business['business_id'] == 'l5PuzGq6hETve3H06tKjVA','city'] = 'Mount Oliver'
food_business.loc[food_business['business_id'] == '82bfom6b5BQlnnd4m3wwew','city'] = 'Paradise Valley'
food_business.loc[food_business['business_id'] == 'M8opVyzRVlfakUC8-b5D-w','city'] = 'Surprise'
food_business.loc[food_business['business_id'] == 'XjwgMrBeBeOKQTYiXfRYLQ','city'] = 'Sutersville'
food_business.loc[food_business['business_id'] == 'rpK_kvpIoz-j-V-Nmn83mg','city'] = 'Newbury Township'
food_business.loc[food_business['business_id'] == 'iB0_iENuscini2VcyG0q4w','city'] = 'Gilbert'
food_business.loc[food_business['business_id'] == 'EpwwKgTt97JL43_dryuSSA','city'] = 'Warrensville Heights'
food_business.loc[food_business['business_id'] == 'Cx5j8-4ZtK9teAcIAOmvzA','city'] = 'Plum'
food_business.loc[food_business['city'] == 'Pittsburg', 'city'] = 'Pittsburgh'
food_business.loc[food_business['city'] == 'East Liberty', 'city'] = 'Pittsburgh'
food_business.loc[food_business['city'] == 'Lake Wylie', 'city'] = 'Clover'
food_business.loc[food_business['city'] == 'Mc Farland', 'city'] = 'Mcfarland'
food_business.loc[food_business['city'] == 'Presto', 'city'] = 'Preston'
food_business.loc[food_business['city'] == 'Boulder City', 'city'] = 'Boulder'
food_business.loc[food_business['city'] == 'Concord Mills', 'city'] = 'Concord'
food_business.loc[food_business['city'] == 'Mc Murray', 'city'] = 'Canonsburg'
food_business.loc[food_business['city'] == 'Canonsburd', 'city'] = 'Canonsburg'
food_business.loc[food_business['city'] == 'Mcmurray', 'city'] = 'Canonsburg'
food_business.loc[food_business['city'] == 'Mc Kees Rocks', 'city'] = 'Mckees Rocks'
food_business.loc[food_business['city'] == 'Harrison City', 'city'] = 'Harrison'
food_business.loc[food_business['city'] == 'Scottdale', 'city'] = 'Scottsdale'
food_business.loc[food_business['city'] == 'Fort Mcdowell', 'city'] = 'Scottsdale'
food_business.loc[food_business['city'] == 'Bellvue', 'city'] = ' Bellevue'
food_business.loc[food_business['city'] == ' Bellevue', 'city'] = 'Bellevue'
food_business.loc[food_business['city'] == 'Mc Donald', 'city'] = 'Mcdonald'
food_business.loc[food_business['city'] == 'Allison Park', 'city'] = 'Allison'
food_business.loc[food_business['city'] == 'East Mc Keesport', 'city'] = 'East Mckeesport'
food_business.loc[food_business['city'] == 'Harmarville', 'city'] = 'Harmar'
food_business.loc[food_business['city'] == 'Brookpark', 'city'] = 'Brook Park'
food_business.loc[food_business['city'] == 'North Huntington', 'city'] = 'North Huntingdon'
lasvegas_list = ['Enterprise','Paradise','Las  Vegas','Nellis Afb','Spring Valley','City Center','South Las Vegas','Lasvegas','Nellis Air Force Base']
food_business.loc[food_business['city'].isin(lasvegas_list) , 'city'] = 'Las Vegas'
food_business.loc[food_business['city'] == 'Stoney Creek', 'city'] = 'Whitsett'
food_business.loc[food_business['city'] == 'San Tan Valley', 'city'] = 'Queen Creek'
food_business.loc[food_business['city'] == 'Cuyahoga Fls', 'city'] = 'Cuyahoga Falls'
phoenix_list = ['Central City','Ahwatukee','Phx','Central City Village','Anthem']
food_business.loc[food_business['city'].isin(phoenix_list) , 'city'] = 'Phoenix'
food_business.loc[food_business['city'] == 'Higley', 'city'] = 'Gilbert'
food_business.loc[food_business['city'] == 'Library', 'city'] = 'South Park'
food_business.loc[food_business['city'] == 'North Olmstead', 'city'] = 'North Olmsted'
food_business.loc[food_business['city'] == 'North Olmsted,', 'city'] = 'North Olmsted'
food_business.loc[food_business['city'] == 'Sun Lakes', 'city'] = 'Chandler'
food_business.loc[food_business['city'] == 'Mentor-On-The-Lake', 'city'] = 'Mentor On The Lake'
food_business.loc[food_business['city'] == 'Mentor On The', 'city'] = 'Mentor On The Lake'
food_business.loc[food_business['city'] == 'Moon Twp', 'city'] = 'Moon Township'
food_business.loc[food_business['city'] == 'Montrose', 'city'] = 'Fairlawn'
food_business.loc[food_business['city'] == 'Novelty', 'city'] = 'Russell'
food_business.loc[food_business['city'] == 'Neville Island', 'city'] = 'Neville'
food_business.loc[(food_business['city'] == 'Cleveland') & (food_business['state_x'] == 'KY'), 'state_x'] = 'OH'
food_business.loc[(food_business['city'] == 'Charlotte') & (food_business['state_x'] == 'SC'), 'state_x'] = 'NC'
census_data.loc[census_data['area'].str.contains('Mentor-On-The-Lake'),'area'] = 'Mentor On The Lake'

# %%
food_business.city = food_business['city'].str.replace(r'^(N )|^(N. )','North ',regex=True)
food_business.city = food_business['city'].str.replace(r'^(Mt. )|^(Mt )','Mount ',regex=True)
food_business.city = food_business['city'].str.replace(r'(St )|(Saint )','St. ',regex=True)
food_business.city = food_business['city'].str.replace(r'Twp','Township',regex=True)
food_business.city = food_business['city'].str.replace(r'(Hts)$|(Hts.)$|(Hghts.)$|(Height)$','Heights',regex=True)
food_business.city = food_business['city'].str.replace(r'Indian Land(.)?','Fort Mill',regex=True)

# %%
food_business.drop(columns=['state_y'], inplace=True)
food_business.rename(columns={'state_x':'state'},inplace=True)

# %%
business_attributes = food_business.loc[:,['business_id','attributes']]

# %%
food_business = food_business.merge(census_data, how='left', left_on=['city','state'],right_on=['area','abbrv'])

# %%
food_business.drop(columns=['is_open','area','abbrv'],inplace=True)

# %%
display(food_business.info())
display(food_business.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34049 entries, 0 to 34048
# Data columns (total 13 columns):
# business_id     34049 non-null object
# name            34049 non-null object
# attributes      33326 non-null object
# city            34049 non-null object
# state_x         34049 non-null object
# categories      34049 non-null object
# stars           34049 non-null float64
# review_count    34049 non-null int64
# latitude        34048 non-null float64
# longitude       34049 non-null float64
# postal_code     34049 non-null object
# state_y         4248 non-null object
# population      4248 non-null float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 3.6+ MB
# None
#               business_id                        name  \
# 0  45bWSZtniwPRiqlivpS8Og  The Coffee Bean & Tea Leaf
# 1  8-NRKkPY1UiFXW20WXKiXg    Filiberto's Mexican Food
# 2  _c3ixq9jYKxhLUB0czi0ug    Original Hamburger Works
# 3  gJ5xSt6147gkcZ9Es0WxlA          Rally's Hamburgers
# 4  3ByGQOVgds2YEu6kzl-XEQ                    Rib Shop
#
#                                           attributes       city state_x  \
# 0  {u'BusinessParking': u'{'garage': False, 'stre...    Phoenix      AZ
# 1  {u'RestaurantsTableService': u'False', u'GoodF...   Avondale      AZ
# 2  {u'Alcohol': u'full_bar', u'HasTV': u'True', u...    Phoenix      AZ
# 3                                               None  Cleveland      OH
# 4  {u'GoodForMeal': u'{'dessert': False, 'latenig...    Phoenix      AZ
#
#                                           categories  stars  review_count  \
# 0                                 Coffee & Tea, Food    4.0            63
# 1                               Mexican, Restaurants    2.5            40
# 2  Bars, Sports Bars, Dive Bars, Burgers, Nightli...    4.0           277
# 3                    Fast Food, Burgers, Restaurants    3.0             5
# 4  Nightlife, Bars, American (Traditional), Sport...    2.5             3
#
#     latitude   longitude postal_code state_y  population
# 0  33.671375 -112.030017       85024     NaN         NaN
# 1  33.448106 -112.341302       85323     NaN         NaN
# 2  33.479807 -112.091188       85007     NaN         NaN
# 3  41.499989  -81.666375       44115     NaN         NaN
# 4  33.495298 -112.236076       85033     NaN         NaN

# %%
food_business.rename(columns={'state_x':'state','state_y':'state_full'},inplace=True)

# %%
food_business = food_business.drop_duplicates(['business_id'])

# %%
# Remove cities that are outside US
cities_outside = ['Montreal','Bellagio','The Quay','Main Street','Turks And Caicos Islands']
food_business = food_business.loc[~food_business['city'].isin(cities_outside)]

# %%
census_data.area = census_data.area.str.replace(r'( City)', '')

# %%
food_business = food_business.merge(census_data, how='left', left_on=['city','state'],right_on=['area','abbrv'])

food_business.drop(columns=['state_full','area','abbrv'],inplace=True)

food_business.loc[food_business['population_x'].isna(), 'population_x'] = food_business['population_y']
food_business.drop(columns=['population_y'],inplace=True)

food_business.rename(columns={'state_x':'state','state_y':'state_full','population_x':'population'},inplace=True)

# %%
census_data.area = census_data.area.str.replace(r'( Township)|( Village)|( Municipality)', '')

# %%
food_business = food_business.merge(census_data, how='left', left_on=['city','state'],right_on=['area','abbrv'])

# %%
food_business.drop(columns=['state_full','area','abbrv'],inplace=True)
food_business.loc[food_business['population_x'].isna(), 'population_x'] = food_business['population_y']
food_business.drop(columns=['population_y'],inplace=True)

food_business.rename(columns={'state_x':'state','state_y':'state_full','population_x':'population'},inplace=True)

# %%
# Remove records with no population
food_business = food_business.loc[~food_business['population'].isna()]
# Out:
# Empty DataFrame
# Columns: [business_id, name, attributes, city, state, categories, stars, review_count, latitude, longitude, postal_code, population, state_full]
# Index: []

# %%
food_business = food_business.drop_duplicates(['business_id'])

# %%
food_business.drop(columns=['latitude','longitude','state_full'],inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33576 entries, 0 to 40994
# Data columns (total 10 columns):
# business_id     33576 non-null object
# name            33576 non-null object
# attributes      32870 non-null object
# city            33576 non-null object
# state           33576 non-null object
# categories      33576 non-null object
# stars           33576 non-null float64
# review_count    33576 non-null int64
# postal_code     33576 non-null object
# population      33576 non-null float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 2.8+ MB
# None

# %%
display(food_business.head())
display(food_business.tail())
display(food_business.info())
# Out:
#               business_id                        name  \
# 0  45bWSZtniwPRiqlivpS8Og  The Coffee Bean & Tea Leaf
# 1  8-NRKkPY1UiFXW20WXKiXg    Filiberto's Mexican Food
# 2  _c3ixq9jYKxhLUB0czi0ug    Original Hamburger Works
# 3  gJ5xSt6147gkcZ9Es0WxlA          Rally's Hamburgers
# 4  3ByGQOVgds2YEu6kzl-XEQ                    Rib Shop
#
#                                           attributes       city state  \
# 0  {u'BusinessParking': u'{'garage': False, 'stre...    Phoenix    AZ
# 1  {u'RestaurantsTableService': u'False', u'GoodF...   Avondale    AZ
# 2  {u'Alcohol': u'full_bar', u'HasTV': u'True', u...    Phoenix    AZ
# 3                                               None  Cleveland    OH
# 4  {u'GoodForMeal': u'{'dessert': False, 'latenig...    Phoenix    AZ
#
#                                           categories  stars  review_count  \
# 0                                 Coffee & Tea, Food    4.0            63
# 1                               Mexican, Restaurants    2.5            40
# 2  Bars, Sports Bars, Dive Bars, Burgers, Nightli...    4.0           277
# 3                    Fast Food, Burgers, Restaurants    3.0             5
# 4  Nightlife, Bars, American (Traditional), Sport...    2.5             3
#
#   postal_code  population
# 0       85024   1626078.0
# 1       85323     84025.0
# 2       85007   1626078.0
# 3       44115    385525.0
# 4       85033   1626078.0
#                   business_id                   name  \
# 40990  0zGeYN8ReYwVj27U7EHOJA          American Cafe
# 40991  K9ukZjvXhDjQZnrrOPqKSw  Montecristo Cigar Bar
# 40992  GdGXb80QKTMRP7AdPHDnuw    Breeze Daiquiri Bar
# 40993  kbaXNZLUyVuWbeQxH-NNKw             Bell's BBQ
# 40994  KleCXFYOmdACcQUvf6_XEg    Walmart Supercenter
#
#                                               attributes       city state  \
# 40990  {u'GoodForMeal': u'{'dessert': False, 'latenig...  Las Vegas    NV
# 40991  {u'WheelchairAccessible': u'True', u'BusinessP...  Las Vegas    NV
# 40992  {u'DogsAllowed': u'True', u'Alcohol': u'full_b...  Las Vegas    NV
# 40993  {u'Alcohol': u'beer_and_wine', u'HasTV': u'Tru...  Henderson    NV
# 40994  {u'BusinessParking': u'{'garage': False, 'stre...    Concord    NC
#
#                                               categories  stars  review_count  \
# 40990         Delis, Restaurants, American (Traditional)    2.5             7
# 40991  Nightlife, Bars, Shopping, Tobacco Shops, Cock...    4.5           108
# 40992           Beer Bar, Cocktail Bars, Nightlife, Bars    4.0             5
# 40993  American (Traditional), American (New), Restau...    4.0           447
# 40994  Mobile Phones, Shopping, Department Stores, Fo...    3.0            26
#
#       postal_code  population
# 40990       89109    641676.0
# 40991       89109    641676.0
# 40992       89109    641676.0
# 40993       89052    302539.0
# 40994       28027     92067.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33576 entries, 0 to 40994
# Data columns (total 10 columns):
# business_id     33576 non-null object
# name            33576 non-null object
# attributes      32870 non-null object
# city            33576 non-null object
# state           33576 non-null object
# categories      33576 non-null object
# stars           33576 non-null float64
# review_count    33576 non-null int64
# postal_code     33576 non-null object
# population      33576 non-null float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 2.8+ MB
# None

# %%
city_population = food_business.loc[:,['city','population']]
city_population = city_population.drop_duplicates()

# %%
city_population.loc[:,'population'] = city_population['population'].astype('int64')
display(city_population.head())
display(city_population.describe())
display(city_population.info())
# Out:
#           city  population
# 0      Phoenix     1626078
# 1     Avondale       84025
# 3    Cleveland      385525
# 6  Streetsboro       16365
# 7  Sun Prairie        2455
#          population
# count  3.440000e+02
# mean   3.358583e+04
# std    1.218314e+05
# min    1.920000e+02
# 25%    3.068500e+03
# 50%    7.785500e+03
# 75%    1.887725e+04
# max    1.626078e+06
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 344 entries, 0 to 40787
# Data columns (total 2 columns):
# city          344 non-null object
# population    344 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 8.1+ KB
# None
# dtype('int64')
