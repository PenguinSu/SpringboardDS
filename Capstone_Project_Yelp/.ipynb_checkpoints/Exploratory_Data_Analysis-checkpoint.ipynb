# %%
# Import packages
# %matplotlib inline 

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from IPython.display import display, HTML

# Set default Seaborn style
sns.set()

# %%
# File path
food_business_file = 'Dataset/food_business.csv'

# %%
# Read in data as DataFrame
food_business = pd.read_csv(food_business_file)

# %%
# Overall info
display(food_business.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33289 entries, 0 to 33288
# Data columns (total 10 columns):
# business_id     33289 non-null object
# name            33289 non-null object
# attributes      32589 non-null object
# city            33289 non-null object
# state           33289 non-null object
# categories      33289 non-null object
# stars           33289 non-null float64
# review_count    33289 non-null int64
# postal_code     33199 non-null float64
# population      33289 non-null int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 2.5+ MB
# None

# %% [markdown]
# During story telling of the dataset, the scatter plot shows there is a slightly positive correlation between population and review count. To further confirm it wasn't happened by chance, I apply bootstrap permutation test on the Pearson correlation coefficient of the two variables. The hypothesis is set as the following,<br>
# $H_0$: There's no correlation between population and review count.<br>
# $H_A$: There is a correlation between population and review count.

# %%
# Explore correlation between review counts and population
review_counts = food_business.loc[:, 'review_count']
population = food_business.loc[:, 'population']
# Compute Pearson correlation coefficient
pearson_r = np.corrcoef(review_counts, population)[0,1]
print('The Pearson correlation coefficient = %f' %pearson_r)
# Out:
# The Pearson correlation coefficient = 0.098716

# %%
# Initialize an array for replicates
perm_replicates = np.empty(10000)

# Generate replicates
for i in range(len(perm_replicates)):
    # Permute number of discharges
    review_counts_permuted = np.random.permutation(review_counts)
    # Compute Pearson correlation
    perm_replicates[i] = np.corrcoef(review_counts_permuted, population)[0,1]

# Compute p-value
p = np.sum(perm_replicates > pearson_r)/len(perm_replicates)
print('p = {:f}'.format(p))
# Out:
# p = 0.000000

# %% [markdown]
# The p-value is small enough to reject the null hypothesis. It implies that there is a positive correlation between population and review count. The Pearson correlation didn't happen by chance.

# %% [markdown]
# Next, I test if stars, review count and population are normal. I use normaltest from Scipy stats package to perform the testing.

# %%
# Normal test on stars
stars = food_business.loc[:, 'stars']
stars_k2, stars_p = stats.normaltest(stars)
print('k2 = %f' % stars_k2)
print('p = {:g}'.format(stars_p))
# Out:
# k2 = 1219.070738
# p = 1.91493e-265

# %%
# Normal test on review counts
review_k2, review_p = stats.normaltest(review_counts)
print('k2 = %f' % review_k2)
print('p = {:g}'.format(review_p))
# Out:
# k2 = 56377.990556
# p = 0

# %%
# Normal test on population
population_k2, population_p = stats.normaltest(population)
print('k2 = %f' % population_k2)
print('p = {:g}'.format(population_p))
# Out:
# k2 = 6067.607592
# p = 0

# %% [markdown]
# The results show that only review counts and population are normal.

# %% [markdown]
# Part of the design of this model is using different size group to predict if the food business is good. Thus, I split the dataset into five groups based on population and apply further exploration on them.

# %%
# Split population to four groups 
first , second, third, fourth, fifth = np.percentile(population, [20,40,60,80,100])
first_group = food_business.loc[food_business.population <= first]
second_group = food_business.loc[(food_business.population > first) & (food_business.population <= second)]
third_group = food_business.loc[(food_business.population > second) & (food_business.population <= third)]
fourth_group = food_business.loc[(food_business.population > third) & (food_business.population <= fourth)]
fifth_group = food_business.loc[(food_business.population > fourth) & (food_business.population <= fifth)]
print('The population of first group is from %d to %d, with %d records' % (min(first_group.population), max(first_group.population), len(first_group)))
print('The population of second group is from %d to %d, with %d records' % (min(second_group.population), max(second_group.population), len(second_group)))
print('The population of third group is from %d to %d, with %d records' % (min(third_group.population), max(third_group.population), len(third_group)))
print('The population of fourth group is from %d to %d, with %d records' % (min(fourth_group.population), max(fourth_group.population), len(fourth_group)))
print('The population of fifth group is from %d to %d, with %d records' % (min(fifth_group.population), max(fifth_group.population), len(fifth_group)))
# Out:
# The population of first group is from 228 to 32297, with 6757 records
# The population of second group is from 32349 to 249950, with 7668 records
# The population of third group is from 253458 to 496401, with 6551 records
# The population of fourth group is from 611648 to 641676, with 5966 records
# The population of fifth group is from 859035 to 1626078, with 6347 records

# %%
# Get the mean of each group
first_review_mean = np.mean(first_group.review_count)
second_review_mean = np.mean(second_group.review_count)
third_review_mean = np.mean(third_group.review_count)
fourth_review_mean = np.mean(fourth_group.review_count)
fifth_review_mean = np.mean(fifth_group.review_count)
print('Review count mean for each group:')
print('First group is %f' % first_review_mean)
print('Second group is %f' % second_review_mean)
print('Third group is %f' % third_review_mean)
print('Fourth group is %f' % fourth_review_mean)
print('Fifth group is %f' % fifth_review_mean)
# Out:
# Review count mean for each group:
# First group is 35.743525
# Second group is 75.790558
# Third group is 70.030072
# Fourth group is 167.533691
# Fifth group is 84.286435

# %%
# Get standard deviation of each group
first_review_std = np.std(first_group.review_count)
second_review_std = np.std(second_group.review_count)
third_review_std = np.std(third_group.review_count)
fourth_review_std = np.std(fourth_group.review_count)
fifth_review_std = np.std(fifth_group.review_count)
print('Review count standard deviation for each group:')
print('First group is %f' % first_review_std)
print('Second group is %f' % second_review_std)
print('Third group is %f' % third_review_std)
print('Fourth group is %f' % fourth_review_std)
print('Fifth group is %f' % fifth_review_std)
# Out:
# Review count standard deviation for each group:
# First group is 58.358020
# Second group is 134.881958
# Third group is 118.092453
# Fourth group is 376.340645
# Fifth group is 156.474360

# %%
# Get median of each group
first_review_median = np.percentile(first_group.review_count, 50)
second_review_median = np.percentile(second_group.review_count, 50)
third_review_median = np.percentile(third_group.review_count, 50)
fourth_review_median = np.percentile(fourth_group.review_count, 50)
fifth_review_median = np.percentile(fifth_group.review_count, 50)
print('Review count median for each group:')
print('First group is %f' % first_review_median)
print('Second group is %f' % second_review_median)
print('Third group is %f' % third_review_median)
print('Fourth group is %f' % fourth_review_median)
print('Fifth group is %f' % fifth_review_median)
# Out:
# Review count median for each group:
# First group is 16.000000
# Second group is 28.000000
# Third group is 27.000000
# Fourth group is 47.000000
# Fifth group is 29.000000

# %% [markdown]
# As we can see from the results above, the fourth group has higher number than the other four groups. There could be noise in the fourth group that cause this. I decided to do a ECDF graph on all five groups to explore their similarity.

# %%
# Create ECDF function
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""
    # Number of data points
    n = len(data)

    # x-data for the ECDF
    x = np.sort(data)
    
    # y-data for the ECDF
    y = np.true_divide(np.arange(1, n+1), n)

    return x, y

# %%
# Plot review count ECDF graphs for all five groups
first_x, first_y = ecdf(first_group['review_count'])
second_x, second_y = ecdf(second_group['review_count'])
third_x, third_y = ecdf(third_group['review_count'])
fourth_x, fourth_y = ecdf(fourth_group['review_count'])
fifth_x, fifth_y = ecdf(fifth_group['review_count'])

_ = plt.plot(first_x, first_y, marker='.', linestyle='none')
_ = plt.plot(second_x, second_y, marker='.', linestyle='none')
_ = plt.plot(third_x, third_y, marker='.', linestyle='none')
_ = plt.plot(fourth_x, fourth_y, marker='.', linestyle='none')
_ = plt.plot(fifth_x, fifth_y, marker='.', linestyle='none')
_ = plt.legend(('Group One','Group Two','Group Three','Group Four','Group Five'), loc='right', facecolor='white')
_ = plt.title('ECDF of Five Groups')
_ = plt.xlabel('Review Count')

# %% [markdown]
# The ECDF graph shows review counts from the five groups have identical distribution. Next, let's look into the groups individually.

# %%
# First Group ECDF plots
ef, nt, nf = np.percentile(first_group['review_count'],[85,90,95])

first_85 = first_group.loc[first_group['review_count'] <= ef]
first_90 = first_group.loc[first_group['review_count'] <= nt]
first_95 = first_group.loc[first_group['review_count'] <= nf]

first_85_x, first_85_y = ecdf(first_85['review_count'])
first_90_x, first_90_y = ecdf(first_90['review_count'])
first_95_x, first_95_y = ecdf(first_95['review_count'])

# %%
fig, ax = plt.subplots(2, 2, sharey=True, figsize=(10,11))
fig.suptitle("Group One ECDF Graphs", fontsize='xx-large', fontweight='semibold')

_ = ax[0,0].plot(first_85_x, first_85_y, marker='.', linestyle='none')
_ = ax[0,0].set_title("85% of Group One")
_ = ax[0,0].set_xlabel("Review Counts")
_ = ax[0,1].plot(first_90_x, first_90_y, marker='.', linestyle='none')
_ = ax[0,1].set_title("90% of Group One")
_ = ax[0,1].set_xlabel("Review Counts")
_ = ax[1,0].plot(first_95_x, first_95_y, marker='.', linestyle='none')
_ = ax[1,0].set_title("95% of Group One")
_ = ax[1,0].set_xlabel("Review Counts")
_ = ax[1,1].plot(first_x, first_y, marker='.', linestyle='none')
_ = ax[1,1].set_title("100% of Group One")
_ = ax[1,1].set_xlabel("Review Counts")

# %% [markdown]
# The mean average review count of Group One is 36, and we can see the slope growing gradually around the point. There seems to be some outliers with greater than 500 reviews.

# %%
# Second Group ECDF plots
ef, nt, nf = np.percentile(second_group['review_count'],[85,90,95])

second_85 = second_group.loc[second_group['review_count'] <= ef]
second_90 = second_group.loc[second_group['review_count'] <= nt]
second_95 = second_group.loc[second_group['review_count'] <= nf]

second_85_x, second_85_y = ecdf(second_85['review_count'])
second_90_x, second_90_y = ecdf(second_90['review_count'])
second_95_x, second_95_y = ecdf(second_95['review_count'])

# %%
fig, ax = plt.subplots(2, 2, sharey=True, figsize=(10,11))
fig.suptitle("Group Two ECDF Graphs", fontsize='xx-large', fontweight='semibold')
_ = ax[0,0].plot(second_85_x, second_85_y, marker='.', linestyle='none', color='orange')
_ = ax[0,0].set_title("85% of Group Two")
_ = ax[0,0].set_xlabel("Review Counts")
_ = ax[0,1].plot(second_90_x, second_90_y, marker='.', linestyle='none', color='orange')
_ = ax[0,1].set_title("90% of Group Two")
_ = ax[0,1].set_xlabel("Review Counts")
_ = ax[1,0].plot(second_95_x, second_95_y, marker='.', linestyle='none', color='orange')
_ = ax[1,0].set_title("95% of Group Two")
_ = ax[1,0].set_xlabel("Review Counts")
_ = ax[1,1].plot(second_x, second_y, marker='.', linestyle='none', color='orange')
_ = ax[1,1].set_title("100% of Group Two")
_ = ax[1,1].set_xlabel("Review Counts")

# %% [markdown]
# The mean average review count of Group One is 76, and we can see the slope growing gradually around the point. There seems to be some outliers with greater than 1000 reviews.

# %%
# Third Group ECDF plots
ef, nt, nf = np.percentile(third_group['review_count'],[85,90,95])

third_85 = third_group.loc[third_group['review_count'] <= ef]
third_90 = third_group.loc[third_group['review_count'] <= nt]
third_95 = third_group.loc[third_group['review_count'] <= nf]

third_85_x, third_85_y = ecdf(third_85['review_count'])
third_90_x, third_90_y = ecdf(third_90['review_count'])
third_95_x, third_95_y = ecdf(third_95['review_count'])

# %%
fig, ax = plt.subplots(2, 2, sharey=True, figsize=(10,11))
fig.suptitle("Group Three ECDF Graphs", fontsize='xx-large', fontweight='semibold')
_ = ax[0,0].plot(third_85_x, third_85_y, marker='.', linestyle='none', color='g')
_ = ax[0,0].set_title("85% of Group Three")
_ = ax[0,0].set_xlabel("Review Counts")
_ = ax[0,1].plot(third_90_x, third_90_y, marker='.', linestyle='none', color='g')
_ = ax[0,1].set_title("90% of Group Three")
_ = ax[0,1].set_xlabel("Review Counts")
_ = ax[1,0].plot(third_95_x, third_95_y, marker='.', linestyle='none', color='g')
_ = ax[1,0].set_title("95% of Group Three")
_ = ax[1,0].set_xlabel("Review Counts")
_ = ax[1,1].plot(third_x, third_y, marker='.', linestyle='none', color='g')
_ = ax[1,1].set_title("100% of Group Three")
_ = ax[1,1].set_xlabel("Review Counts")

# %% [markdown]
# The mean average review count of Group One is 70, and we can see the slope growing gradually around the point. There seems to be some outliers around and greater than 1500 reviews.

# %%
# Fourth Group ECDF plots
ef, nt, nf = np.percentile(fourth_group['review_count'],[85,90,95])

fourth_85 = fourth_group.loc[fourth_group['review_count'] <= ef]
fourth_90 = fourth_group.loc[fourth_group['review_count'] <= nt]
fourth_95 = fourth_group.loc[fourth_group['review_count'] <= nf]

fourth_85_x, fourth_85_y = ecdf(fourth_85['review_count'])
fourth_90_x, fourth_90_y = ecdf(fourth_90['review_count'])
fourth_95_x, fourth_95_y = ecdf(fourth_95['review_count'])

# %%
fig, ax = plt.subplots(2, 2, sharey=True, figsize=(10,11))
fig.suptitle("Group Four ECDF Graphs", fontsize='xx-large', fontweight='semibold')
_ = ax[0,0].plot(fourth_85_x, fourth_85_y, marker='.', linestyle='none', color='r')
_ = ax[0,0].set_title("85% of Group Four")
_ = ax[0,0].set_xlabel("Review Counts")
_ = ax[0,1].plot(fourth_90_x, fourth_90_y, marker='.', linestyle='none', color='r')
_ = ax[0,1].set_title("90% of Group Four")
_ = ax[0,1].set_xlabel("Review Counts")
_ = ax[1,0].plot(fourth_95_x, fourth_95_y, marker='.', linestyle='none', color='r')
_ = ax[1,0].set_title("95% of Group Four")
_ = ax[1,0].set_xlabel("Review Counts")
_ = ax[1,1].plot(fourth_x, fourth_y, marker='.', linestyle='none', color='r')
_ = ax[1,1].set_title("100% of Group Four")
_ = ax[1,1].set_xlabel("Review Counts")

# %% [markdown]
# The mean average review count of Group One is 168, and we can see the slope growing gradually around the point. There seems to be some outliers closed to and greater than 4000 reviews.

# %%
# Fifth Group ECDF plots
ef, nt, nf = np.percentile(fifth_group['review_count'],[85,90,95])

fifth_85 = fifth_group.loc[fifth_group['review_count'] <= ef]
fifth_90 = fifth_group.loc[fifth_group['review_count'] <= nt]
fifth_95 = fifth_group.loc[fifth_group['review_count'] <= nf]

fifth_85_x, fifth_85_y = ecdf(fifth_85['review_count'])
fifth_90_x, fifth_90_y = ecdf(fifth_90['review_count'])
fifth_95_x, fifth_95_y = ecdf(fifth_95['review_count'])

# %%
fig, ax = plt.subplots(2, 2, sharey=True, figsize=(10,11))
fig.suptitle("Group Five ECDF Graphs", fontsize='xx-large', fontweight='semibold')
_ = ax[0,0].plot(fifth_85_x, fifth_85_y, marker='.', linestyle='none', color='#856798')
_ = ax[0,0].set_title("85% of Group Five")
_ = ax[0,0].set_xlabel("Review Counts")
_ = ax[0,1].plot(fifth_90_x, fifth_90_y, marker='.', linestyle='none', color='#856798')
_ = ax[0,1].set_title("90% of Group Five")
_ = ax[0,1].set_xlabel("Review Counts")
_ = ax[1,0].plot(fifth_95_x, fifth_95_y, marker='.', linestyle='none', color='#856798')
_ = ax[1,0].set_title("95% of Group Five")
_ = ax[1,0].set_xlabel("Review Counts")
_ = ax[1,1].plot(fifth_x, fifth_y, marker='.', linestyle='none', color='#856798')
_ = ax[1,1].set_title("100% of Group Five")
_ = ax[1,1].set_xlabel("Review Counts")

# %% [markdown]
# The mean average review count of Group One is 84, and we can see the slope growing gradually around the point. There seems to be some outliers with greater than 1500 reviews.

# %%
# Look into review count larger than the mean reivew count for first group based on state
# Get values counts by state and add a column to mark all as group one
review_state1 = first_group.loc[first_group['review_count'] > first_review_mean].groupby('state').business_id.count()
review_state1 = review_state1.reset_index(name='counts')
review_state1['group'] = 'One'
# Get values counts by state and add a column to mark all as group two
review_state2 = second_group.loc[second_group['review_count'] > second_review_mean].groupby('state').business_id.count()
#display(review_state2)
review_state2 = review_state2.reset_index(name='counts')
review_state2['group'] = 'Two'
# Get values counts by state and add a column to mark all as group three
review_state3 = third_group.loc[third_group['review_count'] > third_review_mean].groupby('state').business_id.count()
review_state3 = review_state3.reset_index(name='counts')
review_state3['group'] = 'Three'
# Get values counts by state and add a column to mark all as group four
review_state4 = fourth_group.loc[fourth_group['review_count'] > fourth_review_mean].groupby('state').business_id.count()
review_state4 = review_state4.reset_index(name='counts')
review_state4['group'] = 'Four'
# Get values counts by state and add a column to mark all as group five
review_state5 = fifth_group.loc[fifth_group['review_count'] > fifth_review_mean].groupby('state').business_id.count()
review_state5 = review_state5.reset_index(name='counts')
review_state5['group'] = 'Five'
# Merge all five dataframes to compare
review_state = pd.concat([review_state1, review_state2, review_state3, review_state4, review_state5], ignore_index=True)
review_state = review_state[['group', 'state', 'counts']]
display(review_state)
# Plot bar plot
fig, ax = plt.subplots(1,1, figsize=(17,15))
sns.barplot('group', 'counts', data=review_state, hue='state', ax=ax)
_ = ax.set_title("Food Businesses Distribution in Each Group by State", fontsize='x-large', fontweight='semibold')
_ = ax.set_ylim(0, 1660)
_ = ax.set_yticks(np.arange(0, 1661,50))
_ = ax.legend(fontsize='large', facecolor='w', framealpha=0.6, edgecolor='w', title='state', handlelength=5)
_ = plt.show()
# Out:
#     group state  counts
# 0     One    AZ     132
# 1     One    IL       9
# 2     One    IN       6
# 3     One    KY       1
# 4     One    NC     209
# 5     One    OH     663
# 6     One    OR       6
# 7     One    PA     240
# 8     One    SC      60
# 9     One    WI     591
# 10    Two    AZ    1638
# 11    Two    IL      85
# 12    Two    NC      80
# 13    Two    NV      85
# 14    Two    OH     133
# 15    Two    PA       8
# 16  Three    AZ     654
# 17  Three    NV     325
# 18  Three    OH     283
# 19  Three    PA     561
# 20   Four    NV    1454
# 21   Five    AZ    1068
# 22   Five    NC     597

# %%
# Look into review count larger than the mean reivew count for first group based on city
print("Group One:")
display(first_group.loc[first_group['review_count'] > first_review_mean].groupby('city').business_id.count().sort_values(ascending=False))
print("Group Two:")
display(second_group.loc[second_group['review_count'] > second_review_mean].groupby('city').business_id.count().sort_values(ascending=False))
print("Group Three:")
display(third_group.loc[third_group['review_count'] > third_review_mean].groupby('city').business_id.count().sort_values(ascending=False))
print("Group Four:")
display(fourth_group.loc[fourth_group['review_count'] > fourth_review_mean].groupby('city').business_id.count().sort_values(ascending=False))
print("Group Five:")
display(fifth_group.loc[fifth_group['review_count'] > fifth_review_mean].groupby('city').business_id.count().sort_values(ascending=False))
# Out:
# Group One:
# city
# Madison                454
# Matthews                65
# Fort Mill               55
# Westlake                50
# Middleton               48
# Cave Creek              43
# Cornelius               40
# Rocky River             34
# Solon                   32
# Monroeville             31
# Fountain Hills          30
# Kent                    29
# North Olmsted           27
# Medina                  25
# Willoughby              25
# Pineville               24
# Litchfield Park         24
# Fitchburg               23
# Independence            23
# Hudson                  22
# Beachwood               22
# Homestead               20
# Avon                    20
# Sun Prairie             19
# Bridgeville             18
# Chagrin Falls           18
# Woodmere                16
# Davidson                16
# Lyndhurst               15
# Fairlawn                15
#                       ...
# Wilkins Township         1
# Millvale                 1
# ...

# %%
display(fourth_group.loc[fourth_group['review_count'] > fourth_review_mean].categories)
# Out:
# 9        Beer, Wine & Spirits, Italian, Food, American ...
# 42       American (New), Restaurants, Food, Breweries, ...
# 44       Bars, American (Traditional), Nightlife, Resta...
# 59       Restaurants, Bars, Nightlife, Caterers, Mexica...
# 119                      Japanese, Sushi Bars, Restaurants
# 182                                   Mexican, Restaurants
# 246               Diners, Sandwiches, Restaurants, Burgers
# 248                  Lounges, Bars, Dance Clubs, Nightlife
# 275             Seafood, Restaurants, Mexican, Gluten-Free
# 317                                     Pizza, Restaurants
# 432                      Japanese, Sushi Bars, Restaurants
# 441                  Restaurants, Bars, Nightlife, Italian
# 605      Restaurants, Bars, Nightlife, American (New), ...
# 623      Breakfast & Brunch, Bars, Food, American (New)...
# 624      Event Planning & Services, Restaurants, Catere...
# 645      Restaurants, Desserts, Bakeries, Food, Sandwiches
# ...

# %%
# Plot NV data from each group based on city
first_nv = first_group.loc[first_group['state'] == 'NV'].groupby('city').business_id.count()
second_nv = second_group.loc[second_group['state'] == 'NV'].groupby('city').business_id.count()
third_nv = third_group.loc[third_group['state'] == 'NV'].groupby('city').business_id.count()
fourth_nv = fourth_group.loc[fourth_group['state'] == 'NV'].groupby('city').business_id.count()
fifth_nv = fifth_group.loc[fifth_group['state'] == 'NV'].groupby('city').business_id.count()

# Set a variable to count how many in each group
total_cnt = 0
labels = []
position = 0

ax = plt.subplot(111)
if not first_nv.empty:
    ax.bar(position, first_nv, color='g', width=0.25, label='Group1')
    total_cnt += len(first_nv)
    labels.append(first_nv.index[0])
    position += 1
if not second_nv.empty:
    ax.bar(position, second_nv, color='r', width=0.25, label='Group2')
    total_cnt += len(second_nv)
    labels.append(second_nv.index[0])
    position += 1
if not third_nv.empty:
    ax.bar(position, third_nv, color='b', width=0.25, label='Group3')
    total_cnt += len(third_nv)
    labels.append(third_nv.index[0])
    position += 1
if not fourth_nv.empty:
    ax.bar(position, fourth_nv, color='y', width=0.25, label='Group4')
    total_cnt += len(fourth_nv)
    labels.append(fourth_nv.index[0])
    position += 1
if not fifth_nv.empty:
    ax.bar(position, fifth_nv, color='purple', width=0.25, label='Group5')
    total_cnt += len(fifth_nv)
    labels.append(fifth_nv.index[0])
    position += 1

_ = plt.xticks(np.arange(total_cnt), labels)
_ = plt.xlabel('City Name')
_ = plt.ylabel('Number of Food Businesses')
_ = plt.title('Food Businesses Distribution of Cities in Nevada',fontsize='large')
plt.legend(facecolor='w')
plt.show()

# %%
# Find values of each city
cities = food_business.loc[food_business['state'] == 'NV'].groupby('city').groups
for city in sorted(cities, key=lambda city: len(cities[city])):
    print('%s %d' %(city, len(cities[city])))
# Out:
# North Las Vegas 376
# Henderson 808
# Las Vegas 5965
